# %% [markdown]
# # Anime Recommendations Project

# %% [markdown]
# # Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import warnings# warning filter
import scipy as sp #pivot egineering


#ML model
from sklearn.metrics.pairwise import cosine_similarity


#default theme and settings
pd.options.display.max_columns

#warning hadle
warnings.filterwarnings("always")
warnings.filterwarnings("ignore")

# %% [markdown]
# # Preprocessing and Data Analysis

# %%
rating_path = "./Data Set/rating.csv"
anime_path = "./Data Set/anime.csv"

# %%
rating_df = pd.read_csv(rating_path)
rating_df.head()
# Out:
#    user_id  anime_id  rating
# 0        1        20      -1
# 1        1        24      -1
# 2        1        79      -1
# 3        1       226      -1
# 4        1       241      -1

# %%
anime_df = pd.read_csv(anime_path)
anime_df.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
print(f"anime set (row, col): {anime_df.shape}\n\nrating set (row, col): {rating_df.shape}")
# Out:
# anime set (row, col): (12294, 7)
#
# rating set (row, col): (7813737, 3)

# %%
print("Anime:\n")
print(anime_df.info())
# Out:
# Anime:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB
# None

# %%
print("Rating:\n")
print(rating_df.info())
# Out:
# Rating:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7813737 entries, 0 to 7813736
# Data columns (total 3 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   user_id   int64
#  1   anime_id  int64
#  2   rating    int64
# dtypes: int64(3)
# memory usage: 178.8 MB
# None

# %% [markdown]
# # Handling Missing Values

# %%
print("Anime missing values (%):\n")
print(round(anime_df.isnull().sum().sort_values(ascending=False)/len(anime_df.index),4)*100) 
# Anime dataset is missing 1.87% of ratings
# Out:
# Anime missing values (%):
#
# rating      1.87
# genre       0.50
# type        0.20
# anime_id    0.00
# name        0.00
# episodes    0.00
# members     0.00
# dtype: float64

# %%
print("Rating missing values (%):\n")
print(round(rating_df.isnull().sum().sort_values(ascending=False)/len(rating_df.index),4)*100)
# Rating dataset does not have any missing values
# Out:
# Rating missing values (%):
#
# user_id     0.0
# anime_id    0.0
# rating      0.0
# dtype: float64

# %%
print(anime_df['type'].mode())
print(anime_df['genre'].mode())
# The mode of "genre" column in anime database is "TV"
# The mode of "type" column in anime database is "Hentai"
# Out:
# 0    TV
# Name: type, dtype: object
# 0    Hentai
# Name: genre, dtype: object

# %%
# deleting anime with 0 rating
anime_df=anime_df[~np.isnan(anime_df["rating"])]

# filling mode value for genre and type
anime_df['genre'] = anime_df['genre'].fillna(
anime_df['genre'].dropna().mode().values[0])

anime_df['type'] = anime_df['type'].fillna(
anime_df['type'].dropna().mode().values[0])

#checking if all null values are filled
anime_df.isnull().sum()
# Out:
# anime_id    0
# name        0
# genre       0
# type        0
# episodes    0
# rating      0
# members     0
# dtype: int64

# %% [markdown]
# # Feature Engineering

# %%
# I have seen earlier that there is a -1 rating,
# this suggests that the user did not register a rating,
# so I will foll the -1 ratings with NaN.
rating_df['rating'] = rating_df['rating'].apply(lambda x: np.nan if x==-1 else x)
rating_df.head(20)
# Out:
#     user_id  anime_id  rating
# 0         1        20     NaN
# 1         1        24     NaN
# 2         1        79     NaN
# 3         1       226     NaN
# 4         1       241     NaN
# 5         1       355     NaN
# 6         1       356     NaN
# 7         1       442     NaN
# 8         1       487     NaN
# 9         1       846     NaN
# 10        1       936     NaN
# 11        1      1546     NaN
# 12        1      1692     NaN
# 13        1      1836     NaN
# 14        1      2001     NaN
# 15        1      2025     NaN
# 16        1      2144     NaN
# 17        1      2787     NaN
# 18        1      2993     NaN
# 19        1      3455     NaN

# %%
# Now, we splice our dataframe
# We want to recommend anime series, so the relevant type is "TV"
anime_df = anime_df[anime_df['type']=='TV']

# JOIN the anime and rating dataframe on "anime_id" to form a new dataframe
rated_anime = rating_df.merge(anime_df, left_on = 'anime_id', right_on = 'anime_id', suffixes= ['_user', ''])

# Project the "user_id", "name", and "rating" only
rated_anime = rated_anime[['user_id', 'name', 'rating']]

# Limit to 10000 users for computational purposes
rated_anime_10000 = rated_anime[rated_anime.user_id <= 10000]
rated_anime_10000.head()
# Out:
#    user_id    name  rating
# 0        1  Naruto    7.81
# 1        3  Naruto    7.81
# 2        5  Naruto    7.81
# 3        6  Naruto    7.81
# 4       10  Naruto    7.81

# %% [markdown]
# # Pivot Table

# %%
# Now, creating a pivot table with users as rows and anime names as columns
# will help us analyze for calculations of similarity

# %%
pivot = rated_anime_10000.pivot_table(index=['user_id'], columns=['name'], values='rating')
pivot.head()
# Out:
# name     .hack//Roots  .hack//Sign  .hack//Tasogare no Udewa Densetsu  009-1  \
# user_id
# 1                 NaN          NaN                                NaN    NaN
# 2                 NaN          NaN                                NaN    NaN
# 3                 NaN          NaN                                NaN    NaN
# 4                 NaN          NaN                                NaN    NaN
# 5                 NaN          NaN                                NaN    NaN
#
# name     07-Ghost  11eyes  12-sai.: Chicchana Mune no Tokimeki  \
# user_id
# 1             NaN    6.49                                  NaN
# 2             NaN     NaN                                  NaN
# 3             NaN     NaN                                  NaN
# 4             NaN     NaN                                  NaN
# 5             NaN     NaN                                  NaN
#
# name     3 Choume no Tama: Uchi no Tama Shirimasenka?  30-sai no Hoken Taiiku  \
# user_id
# 1                                                 NaN                     NaN
# 2                                                 NaN                     NaN
# 3                                                 NaN                     NaN
# 4                                                 NaN                     NaN
# 5                                                 NaN                     NaN
#
# name     91 Days  ...  Zone of the Enders: Dolores, I  \
# user_id           ...
# 1            NaN  ...                             NaN
# 2            NaN  ...                             NaN
# 3            NaN  ...                             NaN
# 4            NaN  ...                             NaN
# 5            NaN  ...                             NaN
#
# name     Zukkoke Knight: Don De La Mancha  ef: A Tale of Melodies.  \
# user_id
# 1                                     NaN                      NaN
# 2                                     NaN                      NaN
# 3                                     NaN                      NaN
# 4                                     NaN                      NaN
# 5                                     NaN                      NaN
#
# name     ef: A Tale of Memories.  gdgd Fairies  gdgd Fairies 2  \
# user_id
# 1                            NaN           NaN             NaN
# 2                            NaN           NaN             NaN
# 3                            NaN           NaN             NaN
# 4                            NaN           NaN             NaN
# 5                            NaN           NaN             NaN
#
# name     iDOLM@STER Xenoglossia  s.CRY.ed  xxxHOLiC  xxxHOLiC Kei
# user_id
# 1                           NaN       NaN       NaN           NaN
# 2                           NaN       NaN       NaN           NaN
# 3                           NaN       NaN       NaN           NaN
# 4                           NaN       NaN       NaN           NaN
# 5                           NaN       NaN      8.11           NaN
#
# [5 rows x 2804 columns]

# %%
# Value Normalization
pivot_n = pivot.apply(lambda x: (x-np.mean(x))/(np.max(x)-np.min(x)), axis=1)

# Filling NaN values as 0
pivot_n.fillna(0, inplace=True)

# Transposing the pivot for the next step
pivot_n = pivot_n.T

# Dropping columns with the values of 0 (user did not rate the anime)
pivot_n = pivot_n.loc[:, (pivot_n != 0).any(axis=0)]

# Using scipy package to convert to sparse matrix format for similarity computation
piv_sparse = sp.sparse.csr_matrix(pivot_n.values)

# %% [markdown]
# # Using the Cosine Similarity Model

# %%
#model based on anime similarity
anime_similarity = cosine_similarity(piv_sparse)

#Df of anime similarities
ani_sim_df = pd.DataFrame(anime_similarity, index = pivot_n.index, columns = pivot_n.index)
ani_sim_df
# Out:
# name                               .hack//Roots  .hack//Sign  \
# name
# .hack//Roots                           1.000000     0.483043
# .hack//Sign                            0.483043     1.000000
# .hack//Tasogare no Udewa Densetsu      0.436756     0.441474
# 009-1                                  0.035721     0.035239
# 07-Ghost                               0.070056     0.089239
# ...                                         ...          ...
# gdgd Fairies 2                         0.000000     0.010797
# iDOLM@STER Xenoglossia                 0.065426     0.048033
# s.CRY.ed                               0.132925     0.155897
# xxxHOLiC                              -0.135748    -0.137902
# xxxHOLiC Kei                          -0.115742    -0.118404
#
# name                               .hack//Tasogare no Udewa Densetsu  \
# name
# .hack//Roots                                                0.436756
# .hack//Sign                                                 0.441474
# .hack//Tasogare no Udewa Densetsu                           1.000000
# 009-1                                                       0.064496
# 07-Ghost                                                    0.057389
# ...                                                              ...
# gdgd Fairies 2                                              0.000000
# iDOLM@STER Xenoglossia                                      0.070611
# s.CRY.ed                                                    0.104973
# xxxHOLiC                                                   -0.133673
# xxxHOLiC Kei                                               -0.101508
#
# name                                  009-1  07-Ghost    11eyes  \
# name
# .hack//Roots                       0.035721  0.070056  0.122621
# .hack//Sign                        0.035239  0.089239  0.093153
# .hack//Tasogare no Udewa Densetsu  0.064496  0.057389  0.092265
# 009-1                              1.000000  0.012034  0.061638
# 07-Ghost                           0.012034  1.000000  0.164189
# ...                                     ...       ...       ...
# gdgd Fairies 2                     0.000000 -0.000355  0.001218
# iDOLM@STER Xenoglossia             0.013543  0.021332  0.068340
# s.CRY.ed                           0.012651  0.051022  0.023177
# xxxHOLiC                          -0.082850 -0.097623 -0.154606
# xxxHOLiC Kei                      -0.058980 -0.111422 -0.142716
#
# name                               12-sai.: Chicchana Mune no Tokimeki  \
# name
# .hack//Roots                                                  0.004887
# .hack//Sign                                                   0.003677
# .hack//Tasogare no Udewa Densetsu                             0.005965
# 009-1                                                         0.011157
# 07-Ghost                                                      0.009277
# ...                                                                ...
# gdgd Fairies 2                                                0.000000
# iDOLM@STER Xenoglossia                                        0.042430
# s.CRY.ed                                                      0.000000
# xxxHOLiC                                                     -0.009722
# xxxHOLiC Kei                                                 -0.011184
#
# name                               3 Choume no Tama: Uchi no Tama Shirimasenka?  \
# name
# .hack//Roots                                                           0.000000
# .hack//Sign                                                            0.000000
# .hack//Tasogare no Udewa Densetsu                                      0.000000
# 009-1                                                                  0.000000
# 07-Ghost                                                               0.000548
# ...                                                                         ...
# gdgd Fairies 2                                                         0.000000
# iDOLM@STER Xenoglossia                                                 0.000000
# s.CRY.ed                                                               0.000000
# xxxHOLiC                                                               0.000000
# xxxHOLiC Kei                                                           0.000000
#
# name                               30-sai no Hoken Taiiku   91 Days  ...  \
# name                                                                 ...
# .hack//Roots                                     0.051610 -0.025314  ...
# .hack//Sign                                      0.059214 -0.023532  ...
# .hack//Tasogare no Udewa Densetsu                0.043266 -0.021194  ...
# 009-1                                            0.002477 -0.023557  ...
# 07-Ghost                                         0.044063 -0.025039  ...
# ...                                                   ...       ...  ...
# gdgd Fairies 2                                   0.000000 -0.016189  ...
# iDOLM@STER Xenoglossia                           0.010935 -0.042748  ...
# s.CRY.ed                                         0.011593 -0.009030  ...
# xxxHOLiC                                        -0.097098  0.033333  ...
# xxxHOLiC Kei                                    -0.092657  0.026222  ...
#
# name                               Zone of the Enders: Dolores, I  \
# name
# .hack//Roots                                             0.065054
# .hack//Sign                                              0.076632
# .hack//Tasogare no Udewa Densetsu                        0.030686
# 009-1                                                    0.008970
# 07-Ghost                                                 0.009376
# ...                                                           ...
# gdgd Fairies 2                                           0.000000
# iDOLM@STER Xenoglossia                                   0.018833
# s.CRY.ed                                                 0.026179
# xxxHOLiC                                                -0.025580
# xxxHOLiC Kei                                            -0.015119
#
# name                               Zukkoke Knight: Don De La Mancha  \
# name
# .hack//Roots                                                    0.0
# .hack//Sign                                                     0.0
# .hack//Tasogare no Udewa Densetsu                               0.0
# 009-1                                                           0.0
# 07-Ghost                                                        0.0
# ...                                                             ...
# gdgd Fairies 2                                                  0.0
# iDOLM@STER Xenoglossia                                          0.0
# s.CRY.ed                                                        0.0
# xxxHOLiC                                                        0.0
# xxxHOLiC Kei                                                    0.0
#
# name                               ef: A Tale of Melodies.  \
# name
# .hack//Roots                                     -0.113007
# .hack//Sign                                      -0.111885
# .hack//Tasogare no Udewa Densetsu                -0.119785
# 009-1                                            -0.030307
# 07-Ghost                                         -0.084299
# ...                                                    ...
# gdgd Fairies 2                                   -0.003648
# iDOLM@STER Xenoglossia                           -0.124561
# s.CRY.ed                                         -0.015562
# xxxHOLiC                                          0.215747
# xxxHOLiC Kei                                      0.208436
#
# name                               ef: A Tale of Memories.  gdgd Fairies  \
# name
# .hack//Roots                                     -0.108576      0.000000
# .hack//Sign                                      -0.122537      0.011767
# .hack//Tasogare no Udewa Densetsu                -0.129481      0.000000
# 009-1                                            -0.031157      0.000000
# 07-Ghost                                         -0.080929     -0.000472
# ...                                                    ...           ...
# gdgd Fairies 2                                   -0.007009      0.776453
# iDOLM@STER Xenoglossia                           -0.126264      0.008778
# s.CRY.ed                                         -0.027255      0.010670
# xxxHOLiC                                          0.223329     -0.011312
# xxxHOLiC Kei                                      0.225763      0.000000
#
# name                               gdgd Fairies 2  iDOLM@STER Xenoglossia  \
# name
# .hack//Roots                             0.000000                0.065426
# .hack//Sign                              0.010797                0.048033
# .hack//Tasogare no Udewa Densetsu        0.000000                0.070611
# 009-1                                    0.000000                0.013543
# 07-Ghost                                -0.000355                0.021332
# ...                                           ...                     ...
# gdgd Fairies 2                           1.000000                0.006611
# iDOLM@STER Xenoglossia                   0.006611                1.000000
# s.CRY.ed                                 0.009750                0.003082
# xxxHOLiC                                -0.010336               -0.089927
# xxxHOLiC Kei                             0.000000               -0.063873
#
# name                               s.CRY.ed  xxxHOLiC  xxxHOLiC Kei
# name
# .hack//Roots                       0.132925 -0.135748     -0.115742
# .hack//Sign                        0.155897 -0.137902     -0.118404
# .hack//Tasogare no Udewa Densetsu  0.104973 -0.133673     -0.101508
# 009-1                              0.012651 -0.082850     -0.058980
# 07-Ghost                           0.051022 -0.097623     -0.111422
# ...                                     ...       ...           ...
# gdgd Fairies 2                     0.009750 -0.010336      0.000000
# iDOLM@STER Xenoglossia             0.003082 -0.089927     -0.063873
# s.CRY.ed                           1.000000 -0.068192     -0.055123
# xxxHOLiC                          -0.068192  1.000000      0.710562
# xxxHOLiC Kei                      -0.055123  0.710562      1.000000
#
# [2804 rows x 2804 columns]

# %%
ani_sim_df[["Nanatsu no Taizai"]]
# Out:
# name                               Nanatsu no Taizai
# name
# .hack//Roots                               -0.068064
# .hack//Sign                                -0.067654
# .hack//Tasogare no Udewa Densetsu          -0.059080
# 009-1                                      -0.034479
# 07-Ghost                                   -0.079788
# ...                                              ...
# gdgd Fairies 2                             -0.004078
# iDOLM@STER Xenoglossia                     -0.051665
# s.CRY.ed                                   -0.042605
# xxxHOLiC                                    0.093982
# xxxHOLiC Kei                                0.075390
#
# [2804 rows x 1 columns]

# %%
def anime_recommendation(ani_name):
    """
    This function will return the top 5 shows with the highest cosine similarity value and show match percent
    
    example:
    >>>Input: 
    
    anime_recommendation('Death Note')
    
    >>>Output: 
    
    Recommended because you watched Death Note:

                    #1: Code Geass: Hangyaku no Lelouch, 57.35% match
                    #2: Code Geass: Hangyaku no Lelouch R2, 54.81% match
                    #3: Fullmetal Alchemist, 51.07% match
                    #4: Shingeki no Kyojin, 48.68% match
                    #5: Fullmetal Alchemist: Brotherhood, 45.99% match 

               
    """
    
    number = 1
    print('Recommended because you watched {}:\n'.format(ani_name))
    for anime in ani_sim_df.sort_values(by = ani_name, ascending = False).index[1:6]:
        print(f'#{number}: {anime}, {round(ani_sim_df[anime][ani_name]*100,2)}% match')
        number +=1

# %%
anime_recommendation("Mahouka Koukou no Rettousei")
# Out:
# Recommended because you watched Mahouka Koukou no Rettousei:
#
# #1: Dungeon ni Deai wo Motomeru no wa Machigatteiru Darou ka, 39.44% match
# #2: Rakudai Kishi no Cavalry, 37.33% match
# #3: Tokyo Ravens, 34.89% match
# #4: Mondaiji-tachi ga Isekai kara Kuru Sou Desu yo?, 34.77% match
# #5: Nisekoi, 34.56% match

# %% [markdown]
# inspired by Yonatan Rabinovich, https://www.kaggle.com/yonatanrabinovich
